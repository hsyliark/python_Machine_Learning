# %%
#pip로 인스톨된 numpy모듈을 파이썬에서 사용할수있게 가져옴
##이때 numpy np라는 이름으로 쓰겠다라고 선언
## np는 사용자가 만든 이름
## np는 통계분석, 수치계산 전문인 numpy의 다양한 명령어를 갖고있음
## 다양한명령어는  np.명령어를 사용   예) np.mean(값)
import numpy as np

# %%
Age=[30,25,21,50]
Age
# Out:
# [30, 25, 21, 50]

# %%
np.mean(Age)
# Out:
# 31.5

# %%
#Indexing (0번부터 시작함)
Age[1]
# Out:
# 25

# %%
Age[0]
# Out:
# 30

# %%
Age[3]
# Out:
# 50

# %%
Age[-1]
# Out:
# 50

# %%
len(Age)
# Out:
# 4

# %%
Age[len(Age)-1]
# Out:
# 50

# %%
Len_cnt=len(Age)
Age[Len_cnt-1]
# Out:
# 50

# %%
print(Len_cnt)
# Out:
# 4

# %%
#난수생성(0부터 1까지의 범위에서 임의의 난수 생성)
np.random.rand(1000)
# Out:
# array([0.15095335, 0.91421576, 0.65523784, 0.54071768, 0.52811249,
#        0.78714532, 0.9368752 , 0.82873351, 0.23677627, 0.5870089 ,
#        0.82113906, 0.16112381, 0.79260669, 0.14728244, 0.56653152,
#        0.46014666, 0.21657172, 0.34273777, 0.71438432, 0.20696857,
#        0.7129868 , 0.54829458, 0.89296034, 0.53245917, 0.39773727,
#        0.5223587 , 0.3097005 , 0.42750255, 0.01845219, 0.9312356 ,
#        0.60034617, 0.91268961, 0.76965153, 0.66868232, 0.59861204,
#        0.05323928, 0.93221013, 0.13719298, 0.61966484, 0.50147347,
#        0.57008476, 0.03945168, 0.84121583, 0.92535383, 0.58621119,
#        0.44405643, 0.6362913 , 0.19221651, 0.23661643, 0.27352773,
#        0.74291301, 0.37498297, 0.90766359, 0.29375745, 0.00553115,
#        0.51952943, 0.90442031, 0.5319792 , 0.74690626, 0.96292479,
#        0.8330933 , 0.4821786 , 0.28592414, 0.00665903, 0.32697488,
#        0.5875781 , 0.18362549, 0.75258841, 0.13931815, 0.50597427,
# ...

# %%
#0부터 5-1 중 난수 1개 추출
np.random.randint(0,5)
# Out:
# 1

# %%
rn=np.random.randint(0,4)
Age[rn]
# Out:
# 50
