# %% [markdown]
# ## input 17, hidden layer 20->12, output 1 // relu/tanh/sigmoid, adam, mean_squared_error, 30, 10
# ### 0.8511

# %%
# need library
import numpy as np
import tensorflow as tf
# warning remove
if type(tf.contrib) != type(tf):
    tf.contrib._warning = None

# 딥러닝 구동에 필요한 케라스 함수
from keras.models import Sequential
from keras.layers import Dense

# 실행할 때마다 같은 결과를 얻기 위함
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# surgery patient data
Data_set = np.loadtxt("../dataset/ThoraricSurgery.csv", delimiter = ',') # np.array
Data_set

X = Data_set[:,0:17] # 환자 기록
Y = Data_set[:,17] # 수술 결과

# 딥러닝 구조 결정
model = Sequential()
# danse : 연결
model.add(Dense(20, input_dim = 17, activation = 'relu')) # 1층
model.add(Dense(12, activation = 'tanh')) # 2층
model.add(Dense(1, activation = 'sigmoid')) # 3층

# 딥러닝 실행
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, Y, epochs = 30, batch_size = 10)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0809 10:14:50.664219  1948 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0809 10:14:50.664219  1948 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0809 10:14:50.664219  1948 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...
